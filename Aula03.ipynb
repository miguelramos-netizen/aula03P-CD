# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/aula03P-CD/blob/main/Aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "Miguel"
# !git config --global user.email "miguel.ramos@sou.unijui.edu.br"
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=Miguel
# user.email=miguel.ramos@sou.unijui.edu.br
# init.defaultbranch=main

# %%
# !git clone https://github.com/miguelramos-netizen/aula03P-CD.git
# Out:
# Cloning into 'aula03P-CD'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd aula03P-CD
# !ls
# !git status
# !git remote -v
# Out:
# /aula03P-CD
# README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/miguelramos-netizen/aula03P-CD.git (fetch)
# origin	https://github.com/miguelramos-netizen/aula03P-CD.git (push)

# %%
# %%writefile README.md
# # PCD - Aula 03
# Arquivos da Aula 03: Colab, GitHub e Git.
# ## Autor
# Miguel
# Out:
# Overwriting README.md

# %%
# !git add README.md
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   README.md

# %%
# !git commit -m "Primeira alteração no readme"
# Out:
# [main 493d864] Primeira alteração no readme
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: C0F8-7C0B
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as miguelramos-netizen
# github.com
#   ✓ Logged in to github.com account miguelramos-netizen (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'

# %% [markdown]
# pull, trazer do repositorio p minha maquina
# !git pull origin main
