# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelramos-netizen/aula03P-CD/blob/main/Exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "Miguel"
# !git config --global user.email "miguel.ramos@sou.unijui.edu.br"
# !git config --global init.defaultBranch main
# !git config --global --list

# !git clone https://github.com/miguelramos-netizen/aula03P-CD.git

# %cd aula03P-CD
# !ls
# !git status
# !git remote -v
# Out:
# git version 2.34.1
# user.name=Miguel
# user.email=miguel.ramos@sou.unijui.edu.br
# init.defaultbranch=main
# Cloning into 'aula03P-CD'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.
# /content/aula03P-CD
# Aula03.ipynb  README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/miguelramos-netizen/aula03P-CD.git (fetch)
# origin	https://github.com/miguelramos-netizen/aula03P-CD.git (push)

# %%
a = 5
b = 8
c = 7

media = (a + b + c) / 3



print("Media é", media)
# Out:
# Media é 6.666666666666667
